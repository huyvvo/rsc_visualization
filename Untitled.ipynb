# %%
import numpy as np
from time import time


import pandas as pd
import seaborn as sns
from tqdm import trange, tqdm
from PIL import Image, ImageDraw
import math
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, AutoMinorLocator
import argparse
from matplotlib import cm
from pathlib import Path

sns.set_theme(style="darkgrid")
from collections import Counter
# Out:
# /home/huyvvo/anaconda3/envs/fairvit+py38-cu117-pt20-nightly/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
clusters = {}
for i in range(10):
    clusters[i] = np.load(f'/home/huyvvo/data/tmp/sorted_clusters{i}.npy/sorted_clusters.npy', allow_pickle=True)

cluster_sizes = {}
for i in range(10):
    cluster_sizes[i] = np.sort([len(el) for el in clusters[i]])[::-1]

# %%
for i in range(0,10):
    print(cluster_sizes[i])
    # plt.plot(range(20000), cluster_sizes[i], label=i)

plt.legend()
# plt.yscale('log')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [19605 19317 19235 ...   901   816   806]
# [61055 60922 56329 ...    90    76    69]
# [115225  91847  87692 ...    368    349    269]
# [187856 120620 109726 ...    289    187     60]
# [233430 113267 108363 ...    175     80     53]
# [143513 136889 108475 ...    100     84     38]
# [174325 130423 106078 ...    134    106     52]
# [175736 168729  95140 ...     28     20      8]
# [289058 112091  99465 ...     99     17     12]
# [411293 111602  91049 ...     66     62     59]

# %%
np.sort([len(el) for el in clusters[9]])[::-1]
# Out:
# array([411293, 111602,  91049, ...,     66,     62,     59])

# %%
H = [9.844124425163377, 9.75040131290218, 9.705694067995639, 9.68010736150655, 9.660467710383273, 9.646188052450714, 9.633895855282972, 9.62725125906878, 9.619197420600175, 9.603724016677363, 9.599348332881005, 9.591374907467399, 9.578810965961294, 9.575638384689785, 9.568258517368188, 9.552059879859184, 9.555633116015951, 9.55770069135544, 9.558656715752278, 9.556794228297784, 9.549041262732667, 9.548338738792124, 9.545309709517172, 9.54031526594164, 9.538846562874841, 9.5350761917359, 9.530871258959765, 9.528989887994147, 9.526979331269379, 9.526945849537695, 9.519802831809484, 9.517157591919418, 9.512231533247919, 9.514097187282054, 9.507507464573369, 9.507129476205549, 9.501821164077528, 9.50232449666084, 9.500260280366373, 9.499322198363618, 9.494970095262806, 9.49719068593415, 9.495508141274648, 9.498020205594075, 9.495530029977111, 9.481116584406927, 9.475960995103108, 9.47795363362367, 9.481512789988011, 9.484782019773968, 9.482280368274111, 9.474819796358883, 9.453202570240698, 9.44498421525064, 9.47619809457419, 9.47760831830619, 9.473276043717506, 9.474977025878895, 9.473351899355304, 9.473052526030493, 9.464819641303274, 9.463447460938221, 9.464844346450255, 9.461195685587766, 9.460538665561232, 9.459799046151897, 9.458265085134553, 9.456970665393664, 9.459767818000396, 9.46016344748296, 9.45697320932208, 9.460046559498064, 9.461791113245845, 9.462894849994598, 9.462627997779803, 9.464805650719208, 9.457394329059262, 9.466242321128677, 9.461073354803338, 9.45541020619837, 9.456279121625798, 9.455304542878507, 9.452704831953445, 9.452991175128949, 9.45345170469806, 9.456268472022588, 9.448446652119115, 9.416513543459072, 9.425507657725, 9.444422900929528, 9.450870339474273, 9.453891769043148, 9.448268321092995, 9.450470375734772, 9.450733952696188, 9.440907243941915, 9.445254678621515, 9.44615298785661, 9.447955884693586, 9.44771448907703]

# %%
plt.plot(range(1,len(H)+1), H)
plt.title('Entropy of cluster size during resampling-clustering')
plt.show()
